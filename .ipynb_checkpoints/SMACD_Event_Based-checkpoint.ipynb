# %% [markdown]
# ## Common Class

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from ta.trend import SMAIndicator

class Common_Class():

    def __init__(self, ticker_list, benchmark, start, end, interval, capital, transcation_cost, allocation_method, verbose = True):
        self.ticker_list = ticker_list
        self.benchmark = benchmark
        self.start = start
        self.end = end
        self.interval = interval
        self.total_initial_capital = capital # this is the initial capital you want to trade with (Portfolio total capital)
        self.stock_initial_capital = self.capital_allocation_for_each_stock(allocation_method) # inital capital for each stock
        self.stock_capital = self.capital_allocation_for_each_stock(allocation_method) # this capital will change depending on the trade
        # self.capital = capital # this capital will change depending on trades
        self.transaction_cost = transcation_cost # the transaction cost for trading
        self.total_transaction_cost = 0
        self.quantity = self.init_quantity() # quantities of stock to buy/sell
        self.position = self.init_position() # the trades in progress, long or short
        self.trade_count = self.init_trade_count() # Number of trades
        self.portfolio_df = pd.DataFrame()
        self.benchmark_df = None
        self.verbose = verbose # if you want to see detailed output (logs)
        self.prepare_data() # prepares the data

    def capital_allocation_for_each_stock(self, allocation_method):
        stocks_capital = {}
        if allocation_method == 'equal':
            for ticker in self.ticker_list:
                stocks_capital[ticker] = self.total_initial_capital / len(self.ticker_list)
        return stocks_capital

    def init_quantity(self):
        quantity = {}
        for ticker in self.ticker_list:
            quantity[ticker] = 0
        return quantity

    def init_position(self):
        position = {}
        for ticker in self.ticker_list:
            position[ticker] = 0
        return position

    def init_trade_count(self):
        trade_count = {}
        for ticker in self.ticker_list:
            trade_count[ticker] = 0
        return trade_count

    def prepare_data(self):
        # since we are building a common class for all types of strategy, we will not calcualte the moving averages now.
        # we will calculate the returns though.
        # Since most strategies utilise close prices we are only factoring close price. However, you can alter acoordingly.
        self.data = {}
        # Get the data for all the tickers
        for ticker in self.ticker_list:
            stock_data = yf.Ticker(ticker)
            hist_stock = stock_data.history(start = self.start, end = self.end, interval = self.interval)
            bt_data = pd.DataFrame()
            bt_data["Close_Price"] = hist_stock["Close"]
            bt_data["Return"] = np.log(bt_data["Close_Price"] / bt_data["Close_Price"].shift(1))
            bt_data = bt_data.dropna()
            self.data[ticker] = bt_data

        # Get the data for the benchmark
        benchmark_data = yf.Ticker(self.benchmark)
        hist_benchmark = benchmark_data.history(start = self.start, end = self.end, interval = self.interval)
        bt_data = pd.DataFrame()
        bt_data["Close_Price"] = hist_benchmark["Close"]
        bt_data["Benchmark Returns"] = np.log(bt_data["Close_Price"] / bt_data["Close_Price"].shift(1))
        bt_data = bt_data.dropna()
        self.benchmark_df = bt_data


    def close_graph(self, ticker):
        plt.figure(figsize=(15, 5))
        plt.plot(self.data[ticker]["Close_Price"] ,color='black', label='Price', linestyle='dashed')
        plt.xlabel("Days")
        plt.ylabel("Price")
        plt.title("Close Prices of {}".format(ticker))
        plt.legend()
        plt.grid()
        plt.show()

    def return_date_price(self, ticker, bar):
        # A bar is a unit of data at a given time, depends on the interval you choose, it provides you OHLCV and time info
        # Since we have modeled close prices, we will get the price and date
        date = str(self.data[ticker].index[bar])[:10]
        price = self.data[ticker].Close_Price.iloc[bar]
        return date, price

    def realised_balance(self, ticker, bar, verbose=True):
        #Returns you the realised capital in your account at a given time period / bar
        date, price = self.return_date_price(ticker, bar)
        if verbose:
            print("Date :{} | Realised Balance: {:0.2f}".format(date,self.stock_capital[ticker]))
        return self.stock_capital[ticker]

    def unrealised_balance(self, ticker, bar, verbose=True):
        #Returns you the unrealised capital (trades in progress) in your account at a given time period / bar
        date, price = self.return_date_price(ticker, bar)
        ub = self.quantity[ticker] *price
        if verbose:
            print("Date :{} | Unrealised Balance: {:0.2f}".format(date,ub))
        return ub

    def total_balance(self, ticker, bar, verbose=True):
        #Unrealised plus realised
        date, price = self.return_date_price(ticker, bar)
        tb = self.quantity[ticker] *price + self.stock_capital[ticker]
        if verbose:
            print("Date :{} | Total Balance: {:0.2f}".format(date,tb))
        return tb

    def buy_order(self, ticker, bar,quantity=None, dollar=None ):
        date, price = self.return_date_price(ticker, bar)
        if quantity == None:
            quantity = int(dollar/price)
        self.stock_capital[ticker] = self.stock_capital[ticker] - ((quantity * price)*(1 + self.transaction_cost)) # capital will be lost in buying
        self.quantity[ticker] = self.quantity[ticker] + quantity
        self.trade_count[ticker] = self.trade_count[ticker] + 1
        self.total_transaction_cost += self.transaction_cost * (quantity * price)
        if self.verbose:
            print("Bought {} shares of {} at {:0.2f} per share worth {:0.2f} $".format(quantity, ticker, price, quantity * price))
            self.realised_balance(ticker, bar)
            self.unrealised_balance(ticker, bar)
            self.total_balance(ticker, bar)

    def sell_order(self,ticker, bar,quantity=None, dollar=None ):
        date, price = self.return_date_price(ticker, bar)
        if quantity == None:
            quantity = int(dollar/price)
        self.stock_capital[ticker] = self.stock_capital[ticker] + ((quantity * price)*(1 - self.transaction_cost)) # capital will be added after selling
        self.quantity[ticker] = self.quantity[ticker] - quantity
        self.trade_count[ticker] = self.trade_count[ticker] + 1
        self.total_transaction_cost += self.transaction_cost * (quantity * price)
        if self.verbose:
            print("Sold {} shares of {} at {:0.2f} per share worth {:0.2f} $".format(quantity,ticker, price, quantity * price))
            self.realised_balance(ticker, bar)
            self.unrealised_balance(ticker, bar)
            self.total_balance(ticker, bar)

    def daily_portfolio_information(self, bar):
        portfolio_tb = 0
        portfolio_ub = 0
        portfolio_rb = 0
        for ticker in self.ticker_list:
            portfolio_rb += self.realised_balance(ticker, bar, verbose=False)
            portfolio_ub += self.unrealised_balance(ticker, bar, verbose=False)
            portfolio_tb += self.total_balance(ticker, bar, verbose=False)

        date, price = self.return_date_price(ticker, bar)
        self.portfolio_df.loc[date, ['portfolio_tb', 'portfolio_ub', 'portfolio_rb',]] = portfolio_tb, portfolio_ub, portfolio_rb,

    # Close any open position at the end of the backtesting
    def last_trade(self, ticker, bar):
        date, price = self.return_date_price(ticker, bar)
        last_quantity = self.quantity[ticker]
        self.stock_capital[ticker] = self.stock_capital[ticker] + self.quantity[ticker] * price
        self.quantity[ticker] = 0 # as no more quantity now. all will be settled
        self.trade_count[ticker] = self.trade_count[ticker] + 1
        if self.verbose:
            print("Closed open trades for {} shares of {} at {:0.2f} per share worth {:0.2f} $"\
                        .format(last_quantity,ticker, price, last_quantity * price))
            self.total_balance(ticker, bar)

            returns = (self.stock_capital[ticker] - self.stock_initial_capital[ticker]) / self.stock_initial_capital[ticker] * 100
            print("The total capital at end of strategy for {}: {:0.2f}".format(ticker, self.stock_capital[ticker]))
            print( "The strategy returns on investment are {:0.2f} %".format(returns))
            print( "Total trades by strategy for {}: {:0.2f}".format(ticker, self.trade_count[ticker]))

            self.daily_portfolio_information(bar)

            # Add inital total capital to the portfolio df
            self.portfolio_df.index = pd.to_datetime(self.portfolio_df.index)
            self.portfolio_df['portfolio_daily_returns'] = np.log(self.portfolio_df['portfolio_tb'] / self.portfolio_df['portfolio_tb'].shift(1))
            self.portfolio_df.iloc[0, self.portfolio_df.columns.get_loc('portfolio_daily_returns')] = np.log(self.portfolio_df.iloc[0, self.portfolio_df.columns.get_loc('portfolio_tb')]  / self.total_initial_capital)

    def calculate_portfolio_statistics(self):
        total_trade_count = 0
        for trade_count in self.trade_count.values():
            total_trade_count += trade_count

        total_final_capital = 0
        for capital in self.stock_capital.values():
            total_final_capital += capital

        portfolio_log_returns = self.portfolio_df['portfolio_daily_returns'].sum() * 100
        portfolio_normal_returns = (total_final_capital - self.total_initial_capital) / self.total_initial_capital * 100
        portfolio_annual_mean_returns = np.exp(self.portfolio_df['portfolio_daily_returns'].mean() * 252) - 1
        portfolio_annual_regular_std = (np.exp(self.portfolio_df['portfolio_daily_returns']) -1).std() * (252 ** 0.5)
        portfolio_annual_sharpe_ratio = portfolio_annual_mean_returns / portfolio_annual_regular_std

        # Add benchmark returns
        self.benchmark_df.index = pd.to_datetime(self.benchmark_df.index.date)
        self.portfolio_df = self.portfolio_df.merge(self.benchmark_df[['Benchmark Returns']], how='left', left_index=True, right_index=True)
        benchmark_annual_regular_returns = np.exp(self.portfolio_df['Benchmark Returns'].mean() * 252) -1

        # Beta
        matrix = self.portfolio_df[['portfolio_daily_returns', 'Benchmark Returns']].cov()
        beta = matrix.iat[0, 1] / matrix.iat[1, 1]

        # Portfolio information ratio
        self.portfolio_df['portfolio-benchmark'] = self.portfolio_df['portfolio_daily_returns'] - self.portfolio_df['Benchmark Returns']
        average_of_difference = self.portfolio_df['portfolio-benchmark'].mean()
        std_of_difference = self.portfolio_df['portfolio-benchmark'].std()
        daily_ir = average_of_difference / std_of_difference
        annual_ir = daily_ir * (252 ** 0.5)

        # Treynor ratio
        portfolio_treynor_ratio = portfolio_annual_mean_returns / beta

        # Max drawdown
        self.portfolio_df['portfolio_gross_cum_returns'] = self.portfolio_df['portfolio_daily_returns'].cumsum().apply(np.exp)
        self.portfolio_df['portfolio_gross_cum_max_returns'] = self.portfolio_df['portfolio_gross_cum_returns'].cummax()
        max_drawdown = (self.portfolio_df['portfolio_gross_cum_max_returns'] - self.portfolio_df['portfolio_gross_cum_returns']).max()

        # Calmar ratio
        portfolio_calmar_ratio = portfolio_annual_mean_returns / max_drawdown

        # Sortino ratio
        portfolio_negative_returns_df = self.portfolio_df[self.portfolio_df['portfolio_daily_returns'] < 0]
        annual_negative_portfolio_std = (np.exp(portfolio_negative_returns_df['portfolio_daily_returns']) - 1).std() * (252 ** 0.5)
        portfolio_sortino_ratio = portfolio_annual_mean_returns / annual_negative_portfolio_std



        print("Total trade count {} ".format(total_trade_count))
        print("Total transaction cost: {:0.2f} $".format(self.total_transaction_cost))
        print("Starting capital: {}".format(self.total_initial_capital))
        print("Final capital: {:0.2f}".format(total_final_capital))
        print('Log Portfolio returns: {:0.2f} %'.format(portfolio_log_returns))
        print("Normal Portfolio returns: {:0.2f} %".format(portfolio_normal_returns))
        print('Portfolio Annual Mean returns: {:0.2f}'.format(portfolio_annual_mean_returns))
        print('Portfolio Annual Regular std: {:0.2f}'.format(portfolio_annual_regular_std))
        print('Portfolio Annual Sharpe Ratio: {:0.2f}'.format(portfolio_annual_sharpe_ratio))
        print('{} Benchmark Annual Mean returns: {:0.2f}'.format(self.benchmark, benchmark_annual_regular_returns))
        print('Annual Information Ratio: {:0.2f}'.format(annual_ir))
        print('Portfolio Treynor Ratio: {:0.2f}'.format(portfolio_treynor_ratio))
        print('Portfolio Calmar Ratio: {:0.2f}'.format(portfolio_calmar_ratio))
        print('Portfolio Sortino Ratio: {:0.2f}'.format(portfolio_sortino_ratio))

    def visualise_portfolio_performance(self):
            fig, ax = plt.subplots(2, 2, figsize=(15, 8))

            ax[0][0].plot(self.portfolio_df['portfolio_daily_returns'].cumsum())
            ax[0][0].set_title('Portfolio Returns')

            ax[0][1].plot(self.portfolio_df['portfolio_tb'])
            ax[0][1].set_title('Portfolio Total Balance')

            ax[1][0].plot(self.portfolio_df['portfolio_rb'])
            ax[1][0].set_title('Portfolio Realised Balance')

            ax[1][1].plot(self.portfolio_df['portfolio_ub'])
            ax[1][1].set_title('Portfolio Unrealised Balance')

            fig.tight_layout()

# %% [markdown]
# ## Trading Strategy Logic

# %%
class MA_Strategy(Common_Class):
    
    def __init__(self,stock_list, benchmark,start, end, interval, capital, transcation_cost, primary_trend_window,buy_on,long_sl_ATR_multiple,risk_reward_long,
                 close_n_sma_distance_long_multiple,long_rsi_limit,short_sl_ATR_multiple,risk_reward_short,
                 close_n_sma_distance_short_multiple,short_rsi_limit,allocation_method,verbose):
        super().__init__(stock_list, benchmark, start, end, interval, capital, transcation_cost, allocation_method,verbose)
        self.primary_trend_window = primary_trend_window
        self.buy_on= buy_on
        self.long_sl_ATR_multiple = long_sl_ATR_multiple,
        self.risk_reward_long = risk_reward_long,
        self.close_n_sma_distance_long_multiple= close_n_sma_distance_long_multiple,
        self.long_rsi_limit = long_rsi_limit,
        self.short_sl_ATR_multiple = short_sl_ATR_multiple,
        self.risk_reward_short = risk_reward_short,
        self.close_n_sma_distance_short_multiple = close_n_sma_distance_short_multiple,
        self.short_rsi_limit = short_rsi_limit

    def go_long(self, ticker, bar, quantity = None, dollar = None):
        if self.position[ticker] == -1:
            self.buy_order(ticker, bar, quantity = -self.quantity[ticker]) #to clear previous short position and therefore negative quantity.
        if quantity:
            self.buy_order (ticker, bar, quantity = quantity) # to create new fresh order
        elif dollar:
            if dollar == 'all':
                dollar = self.stock_capital[ticker]
                self.buy_order(ticker, bar, dollar = dollar)

    def go_short(self, ticker, bar, quantity = None, dollar = None):
        if self.position[ticker] == 1:
            self.sell_order(ticker, bar, quantity = self.quantity[ticker]) # to clear previous long vposition
        if quantity:
            self.sell_order(ticker, bar, quantity = quantity) # to create new fresh order
        elif dollar:
            if dollar == 'all':
                dollar = self.stock_capital[ticker]
                self.sell_order(ticker, bar, dollar = dollar)


    def visualise_strategy(self, ticker, STMA_window, LTMA_window, axs):
            axs.plot(self.data[ticker]["Close_Price"] ,color='black', label='Price', linestyle='dashed')
            axs.plot(self.data[ticker]["STMA"], color='b', label='Short term MA')
            axs.plot(self.data[ticker]["LTMA"], color='r', label='Long term MA')
            axs.plot(self.data[ticker][self.data[ticker]['Signal'] == 2].index,
                        self.data[ticker]['STMA'][self.data[ticker]['Signal'] == 2],
                        '^', markersize = 15, color = 'g', label = 'buy/long')
            axs.plot(self.data[ticker][self.data[ticker]['Signal'] == -2].index,
                        self.data[ticker]['STMA'][self.data[ticker]['Signal'] == -2],
                        'v', markersize = 15, color = 'r', label = 'sell/short')

            axs.set_xlabel("Days")
            axs.set_ylabel("Price")
            axs.set_title("Moving Averages Crossover {} Vs {} for {}".format(STMA_window, LTMA_window, ticker))
            axs.legend()
            plt.grid()

    def visualise_position(self, ticker, axs):
            axs.plot(self.data[ticker]["Position"])
            axs.set_title("Long/Short status for {}".format(ticker))
            axs.grid()

    def visualise_stock_returns_distribution(self, ticker, axs):
            axs.hist(self.data[ticker]["Strategy_Returns"], bins = 40, label='Strategy Returns', alpha=0.5)
            axs.hist(self.data[ticker]["Stock_Returns"], bins = 40, label='Stock Returns', alpha=0.5)
            axs.set_title("Histogram of Stock Daily Log Returns for {}".format(ticker))
            axs.legend()
            axs.grid()

    def visualise_stock_and_strategy_returns(self, ticker, axs):
            axs.plot(self.data[ticker][["Strategy_Returns"]].cumsum(), label='Strategy_Returns')
            axs.plot(self.data[ticker][["Stock_Returns"]].cumsum(), label='Stock_Returns')
            axs.legend()
            axs.set_title('Stock vs Strategy Returns for {}'.format(ticker))
            axs.grid()

    def run_strategy(self, STMA_window, LTMA_window):
            for ticker in self.data.keys():
                # Get indicators for all the tickers
                indicator_1 = SMAIndicator(close = self.data[ticker]["Close_Price"], window = STMA_window, fillna= False)
                self.data[ticker]["STMA"] = indicator_1.sma_indicator()
                indicator_2 = SMAIndicator(close = self.data[ticker]["Close_Price"], window = LTMA_window, fillna= False)
                self.data[ticker]["LTMA"] = indicator_2.sma_indicator()

            for bar in range(LTMA_window, len(self.data[self.ticker_list[0]])):
                for ticker in self.ticker_list:
                    if self.position[ticker] in [0,-1]: # checking no position or short position
                        if self.data[ticker]["STMA"].iloc[bar]>self.data[ticker]["LTMA"].iloc[bar]:
                            self.go_long(ticker, bar, dollar="all") # go with all money
                            self.position[ticker] = 1 # long created
                            print("-------------------")

                    if self.position[ticker] in [0,1]: # checking no position or long position
                        if self.data[ticker]["STMA"].iloc[bar]<self.data[ticker]["LTMA"].iloc[bar]:
                            self.go_short(ticker, bar, dollar ="all") # go with all money
                            self.position[ticker] = -1 # short created
                            print("---------------------")

                # Get the daily portfolio total balance, unrealised balance and realised balance
                self.daily_portfolio_information(bar)

            # Last trade
            for ticker in self.ticker_list:
                print("-----------------------------------")
                self.last_trade(ticker, bar)

            print("-----------------------------------")
            print("---------- Portfolio statistics ----------")
            self.calculate_portfolio_statistics()


            print(self.portfolio_df.head(20))


            # Visualise portfolio performance
            self.visualise_portfolio_performance()

            # Visualisation strategy for each ticker
            for ticker in self.data.keys():
                # Add position and signal column to the data
                self.data[ticker]['Position'] = np.where(self.data[ticker]['STMA'] > self.data[ticker]['LTMA'], 1.0, -1.0)
                self.data[ticker]['Signal'] = self.data[ticker]['Position'].diff()
                # Add stock returns
                self.data[ticker]['Stock_Returns'] = np.log(self.data[ticker]["Close_Price"] / self.data[ticker]["Close_Price"].shift(1))
                # Add strategy returns
                self.data[ticker]["Strategy_Returns"] = self.data[ticker]["Stock_Returns"] * self.data[ticker]["Position"].shift(1)

                # Visualtions
                fig, ax = plt.subplots(2, 2, figsize=(15, 8))
                self.visualise_strategy(ticker, STMA_window, LTMA_window, axs=ax[0][0])
                self.visualise_position(ticker, axs=ax[0][1])
                self.visualise_stock_and_strategy_returns(ticker, axs=ax[1][0])
                self.visualise_stock_returns_distribution(ticker, axs=ax[1][1])
                fig.tight_layout()
                plt.show()

# %%
primary_trend_window = 50 # 50 
lookback = 652
buy_on = "Open"
verbose = False

# Long Parameters
long_sl_ATR_multiple = 2 # Used for long SL
risk_reward_long = 2    # Used for long TP
close_n_sma_distance_long_multiple = 2.5 # Used to determine how close to SMA can be bought
long_rsi_limit = 80

# Short Params
short_sl_ATR_multiple= 1 # Used for Short SL
risk_reward_short= 1   # Used for Short TP
close_n_sma_distance_short_multiple = 0.5 # Used to determine how close to SMA can be bought
short_rsi_limit = 20

benchmark_stock_symbol = "^GSPC"

start = "2010-04-10"
end = "2022-07-01"

# %%
# configurations
tickers = ["AAPL", "GOOG", "NFLX", "AMZN",] # META excluded because META IPO on 2012, data setsize is different
total_capital = 40000
# strategy for multiple stocks, assuming capital allocation for each stock is equal
A = MA_Strategy(stock_list = tickers,
                benchmark = benchmark_stock_symbol,
                start = start,
                end = end,
                interval = "1d",
                capital = 40000,
                transcation_cost = 0.01,
                primary_trend_window = primary_trend_window,
                buy_on = buy_on,
                long_sl_ATR_multiple = long_sl_ATR_multiple,
                risk_reward_long = risk_reward_long,
                close_n_sma_distance_long_multiple =close_n_sma_distance_long_multiple ,
                long_rsi_limit= long_rsi_limit,
                short_sl_ATR_multiple=short_sl_ATR_multiple,
                risk_reward_short=risk_reward_short,
                close_n_sma_distance_short_multiple=close_n_sma_distance_short_multiple,
                short_rsi_limit=short_rsi_limit,
                allocation_method='equal',
                verbose=True,)
# Run strategy
A.run_strategy(50,200)
# Out:
# Bought 960 shares of AAPL at 10.41 per share worth 9994.23 $
# Date :2011-01-25 | Realised Balance: -94.17
# Date :2011-01-25 | Unrealised Balance: 9994.23
# Date :2011-01-25 | Total Balance: 9900.06
# -------------------
# Bought 647 shares of GOOG at 15.44 per share worth 9989.60 $
# Date :2011-01-25 | Realised Balance: -89.50
# Date :2011-01-25 | Unrealised Balance: 9989.60
# Date :2011-01-25 | Total Balance: 9900.10
# -------------------
# Bought 374 shares of NFLX at 26.68 per share worth 9977.25 $
# Date :2011-01-25 | Realised Balance: -77.02
# Date :2011-01-25 | Unrealised Balance: 9977.25
# Date :2011-01-25 | Total Balance: 9900.23
# -------------------
# Bought 1131 shares of AMZN at 8.84 per share worth 9992.39 $
# Date :2011-01-25 | Realised Balance: -92.31
# Date :2011-01-25 | Unrealised Balance: 9992.39
# Date :2011-01-25 | Total Balance: 9900.08
# -------------------
# Sold 647 shares of GOOG at 13.34 per share worth 8628.56 $
# Date :2011-05-11 | Realised Balance: 8452.78
# Date :2011-05-11 | Unrealised Balance: 0.00
# Date :2011-05-11 | Total Balance: 8452.78
# Sold 633 shares of GOOG at 13.34 per share worth 8441.85 $
# Date :2011-05-11 | Realised Balance: 16810.21
# Date :2011-05-11 | Unrealised Balance: -8441.85
# Date :2011-05-11 | Total Balance: 8368.36
# ---------------------
# Sold 374 shares of NFLX at 18.48 per share worth 6911.52 $
# Date :2011-09-23 | Realised Balance: 6765.38
# Date :2011-09-23 | Unrealised Balance: 0.00
# Date :2011-09-23 | Total Balance: 6765.38
# Sold 366 shares of NFLX at 18.48 per share worth 6763.68 $
# Date :2011-09-23 | Realised Balance: 13461.42
# Date :2011-09-23 | Unrealised Balance: -6763.68
# Date :2011-09-23 | Total Balance: 6697.74
# ---------------------
# Bought 633 shares of GOOG at 15.27 per share worth 9664.50 $
# Date :2011-11-14 | Realised Balance: 7049.07
# Date :2011-11-14 | Unrealised Balance: 0.00
# Date :2011-11-14 | Total Balance: 7049.07
# Bought 461 shares of GOOG at 15.27 per share worth 7038.44 $
# Date :2011-11-14 | Realised Balance: -59.76
# Date :2011-11-14 | Unrealised Balance: 7038.44
# Date :2011-11-14 | Total Balance: 6978.68
# -------------------
# Sold 1131 shares of AMZN at 8.69 per share worth 9831.78 $
# Date :2011-12-29 | Realised Balance: 9641.16
# Date :2011-12-29 | Unrealised Balance: 0.00
# Date :2011-12-29 | Total Balance: 9641.16
# Sold 1109 shares of AMZN at 8.69 per share worth 9640.54 $
# Date :2011-12-29 | Realised Balance: 19185.29
# Date :2011-12-29 | Unrealised Balance: -9640.54
# Date :2011-12-29 | Total Balance: 9544.75
# ---------------------
# Bought 1109 shares of AMZN at 11.20 per share worth 12424.13 $
# Date :2012-05-16 | Realised Balance: 6636.92
# Date :2012-05-16 | Unrealised Balance: 0.00
# Date :2012-05-16 | Total Balance: 6636.92
# Bought 592 shares of AMZN at 11.20 per share worth 6632.18 $
# Date :2012-05-16 | Realised Balance: -61.58
# Date :2012-05-16 | Unrealised Balance: 6632.18
# Date :2012-05-16 | Total Balance: 6570.60
# -------------------
# Sold 461 shares of GOOG at 14.08 per share worth 6489.72 $
# Date :2012-06-21 | Realised Balance: 6365.06
# Date :2012-06-21 | Unrealised Balance: 0.00
# Date :2012-06-21 | Total Balance: 6365.06
# Sold 452 shares of GOOG at 14.08 per share worth 6363.02 $
# Date :2012-06-21 | Realised Balance: 12664.46
# Date :2012-06-21 | Unrealised Balance: -6363.02
# Date :2012-06-21 | Total Balance: 6301.43
# ---------------------
# Bought 452 shares of GOOG at 16.90 per share worth 7639.88 $
# Date :2012-08-24 | Realised Balance: 4948.17
# Date :2012-08-24 | Unrealised Balance: 0.00
# Date :2012-08-24 | Total Balance: 4948.17
# Bought 292 shares of GOOG at 16.90 per share worth 4935.50 $
# Date :2012-08-24 | Realised Balance: -36.68
# Date :2012-08-24 | Unrealised Balance: 4935.50
# Date :2012-08-24 | Total Balance: 4898.82
# -------------------
# Sold 960 shares of AAPL at 16.30 per share worth 15647.81 $
# Date :2012-12-10 | Realised Balance: 15397.17
# Date :2012-12-10 | Unrealised Balance: 0.00
# Date :2012-12-10 | Total Balance: 15397.17
# Sold 944 shares of AAPL at 16.30 per share worth 15387.01 $
# Date :2012-12-10 | Realised Balance: 30630.31
# Date :2012-12-10 | Unrealised Balance: -15387.01
# Date :2012-12-10 | Total Balance: 15243.30
# ---------------------
# Bought 366 shares of NFLX at 13.66 per share worth 5000.61 $
# Date :2012-12-18 | Realised Balance: 8410.81
# Date :2012-12-18 | Unrealised Balance: 0.00
# Date :2012-12-18 | Total Balance: 8410.81
# Bought 615 shares of NFLX at 13.66 per share worth 8402.66 $
# Date :2012-12-18 | Realised Balance: -75.87
# Date :2012-12-18 | Unrealised Balance: 8402.66
# Date :2012-12-18 | Total Balance: 8326.79
# -------------------
# Bought 944 shares of AAPL at 15.51 per share worth 14640.72 $
# Date :2013-09-10 | Realised Balance: 15843.18
# Date :2013-09-10 | Unrealised Balance: 0.00
# Date :2013-09-10 | Total Balance: 15843.18
# Bought 1021 shares of AAPL at 15.51 per share worth 15834.93 $
# Date :2013-09-10 | Realised Balance: -150.09
# Date :2013-09-10 | Unrealised Balance: 15834.93
# Date :2013-09-10 | Total Balance: 15684.84
# -------------------
# Sold 592 shares of AMZN at 15.40 per share worth 9117.10 $
# Date :2014-05-02 | Realised Balance: 8964.35
# Date :2014-05-02 | Unrealised Balance: 0.00
# Date :2014-05-02 | Total Balance: 8964.35
# Sold 582 shares of AMZN at 15.40 per share worth 8963.09 $
# Date :2014-05-02 | Realised Balance: 17837.81
# Date :2014-05-02 | Unrealised Balance: -8963.09
# Date :2014-05-02 | Total Balance: 8874.72
# ---------------------
# Sold 292 shares of GOOG at 27.37 per share worth 7992.00 $
# Date :2014-10-28 | Realised Balance: 7875.40
# Date :2014-10-28 | Unrealised Balance: 0.00
# Date :2014-10-28 | Total Balance: 7875.40
# Sold 287 shares of GOOG at 27.37 per share worth 7855.15 $
# Date :2014-10-28 | Realised Balance: 15652.00
# Date :2014-10-28 | Unrealised Balance: -7855.15
# Date :2014-10-28 | Total Balance: 7796.85
# ---------------------
# Sold 615 shares of NFLX at 52.59 per share worth 32343.73 $
# Date :2014-11-20 | Realised Balance: 31944.42
# Date :2014-11-20 | Unrealised Balance: 0.00
# Date :2014-11-20 | Total Balance: 31944.42
# Sold 607 shares of NFLX at 52.59 per share worth 31923.00 $
# Date :2014-11-20 | Realised Balance: 63548.19
# Date :2014-11-20 | Unrealised Balance: -31923.00
# Date :2014-11-20 | Total Balance: 31625.19
# ---------------------
# Bought 582 shares of AMZN at 18.95 per share worth 11028.90 $
# Date :2015-02-19 | Realised Balance: 6698.62
# Date :2015-02-19 | Unrealised Balance: 0.00
# Date :2015-02-19 | Total Balance: 6698.62
# Bought 353 shares of AMZN at 18.95 per share worth 6689.35 $
# Date :2015-02-19 | Realised Balance: -57.63
# Date :2015-02-19 | Unrealised Balance: 6689.35
# Date :2015-02-19 | Total Balance: 6631.72
# -------------------
# Bought 607 shares of NFLX at 62.88 per share worth 38170.76 $
# Date :2015-03-11 | Realised Balance: 24995.72
# Date :2015-03-11 | Unrealised Balance: 0.00
# Date :2015-03-11 | Total Balance: 24995.72
# Bought 397 shares of NFLX at 62.88 per share worth 24965.06 $
# Date :2015-03-11 | Realised Balance: -218.99
# Date :2015-03-11 | Unrealised Balance: 24965.06
# Date :2015-03-11 | Total Balance: 24746.07
# -------------------
# Bought 287 shares of GOOG at 26.87 per share worth 7710.83 $
# Date :2015-04-30 | Realised Balance: 7864.06
# Date :2015-04-30 | Unrealised Balance: 0.00
# Date :2015-04-30 | Total Balance: 7864.06
# Bought 292 shares of GOOG at 26.87 per share worth 7845.16 $
# Date :2015-04-30 | Realised Balance: -59.56
# Date :2015-04-30 | Unrealised Balance: 7845.16
# Date :2015-04-30 | Total Balance: 7785.61
# -------------------
# Sold 292 shares of GOOG at 26.48 per share worth 7732.45 $
# Date :2015-05-13 | Realised Balance: 7595.57
# Date :2015-05-13 | Unrealised Balance: 0.00
# Date :2015-05-13 | Total Balance: 7595.57
# Sold 286 shares of GOOG at 26.48 per share worth 7573.57 $
# Date :2015-05-13 | Realised Balance: 15093.40
# Date :2015-05-13 | Unrealised Balance: -7573.57
# Date :2015-05-13 | Total Balance: 7519.83
# ---------------------
# Bought 286 shares of GOOG at 33.65 per share worth 9622.90 $
# Date :2015-07-17 | Realised Balance: 5374.27
# Date :2015-07-17 | Unrealised Balance: 0.00
# Date :2015-07-17 | Total Balance: 5374.27
# Bought 159 shares of GOOG at 33.65 per share worth 5349.79 $
# Date :2015-07-17 | Realised Balance: -29.02
# Date :2015-07-17 | Unrealised Balance: 5349.79
# Date :2015-07-17 | Total Balance: 5320.77
# -------------------
# Sold 1021 shares of AAPL at 25.86 per share worth 26404.13 $
# Date :2015-08-28 | Realised Balance: 25989.99
# Date :2015-08-28 | Unrealised Balance: 0.00
# Date :2015-08-28 | Total Balance: 25989.99
# Sold 1004 shares of AAPL at 25.86 per share worth 25964.49 $
# Date :2015-08-28 | Realised Balance: 51694.83
# Date :2015-08-28 | Unrealised Balance: -25964.49
# Date :2015-08-28 | Total Balance: 25730.35
# ---------------------
# Sold 397 shares of NFLX at 89.12 per share worth 35380.64 $
# Date :2016-02-23 | Realised Balance: 34807.84
# Date :2016-02-23 | Unrealised Balance: 0.00
# Date :2016-02-23 | Total Balance: 34807.84
# Sold 390 shares of NFLX at 89.12 per share worth 34756.80 $
# Date :2016-02-23 | Realised Balance: 69217.08
# Date :2016-02-23 | Unrealised Balance: -34756.80
# Date :2016-02-23 | Total Balance: 34460.28
# ---------------------
# Sold 353 shares of AMZN at 28.99 per share worth 10234.71 $
# Date :2016-03-28 | Realised Balance: 10074.73
# Date :2016-03-28 | Unrealised Balance: 0.00
# Date :2016-03-28 | Total Balance: 10074.73
# Sold 347 shares of AMZN at 28.99 per share worth 10060.74 $
# Date :2016-03-28 | Realised Balance: 20034.87
# Date :2016-03-28 | Unrealised Balance: -10060.74
# Date :2016-03-28 | Total Balance: 9974.12
# ---------------------
# Bought 347 shares of AMZN at 31.55 per share worth 10947.85 $
# Date :2016-04-21 | Realised Balance: 8977.54
# Date :2016-04-21 | Unrealised Balance: 0.00
# Date :2016-04-21 | Total Balance: 8977.54
# Bought 284 shares of AMZN at 31.55 per share worth 8960.20 $
# Date :2016-04-21 | Realised Balance: -72.26
# Date :2016-04-21 | Unrealised Balance: 8960.20
# Date :2016-04-21 | Total Balance: 8887.94
# -------------------
# Sold 159 shares of GOOG at 34.21 per share worth 5438.67 $
# Date :2016-06-29 | Realised Balance: 5355.27
# Date :2016-06-29 | Unrealised Balance: 0.00
# Date :2016-06-29 | Total Balance: 5355.27
# Sold 156 shares of GOOG at 34.21 per share worth 5336.06 $
# Date :2016-06-29 | Realised Balance: 10637.97
# Date :2016-06-29 | Unrealised Balance: -5336.06
# Date :2016-06-29 | Total Balance: 5301.91
# ---------------------
# Bought 156 shares of GOOG at 39.16 per share worth 6109.12 $
# Date :2016-08-12 | Realised Balance: 4467.76
# Date :2016-08-12 | Unrealised Balance: 0.00
# Date :2016-08-12 | Total Balance: 4467.76
# Bought 114 shares of GOOG at 39.16 per share worth 4464.35 $
# Date :2016-08-12 | Realised Balance: -41.24
# Date :2016-08-12 | Unrealised Balance: 4464.35
# Date :2016-08-12 | Total Balance: 4423.12
# -------------------
# Bought 1004 shares of AAPL at 24.71 per share worth 24813.14 $
# Date :2016-08-30 | Realised Balance: 26633.56
# Date :2016-08-30 | Unrealised Balance: 0.00
# Date :2016-08-30 | Total Balance: 26633.56
# Bought 1077 shares of AAPL at 24.71 per share worth 26617.29 $
# Date :2016-08-30 | Realised Balance: -249.90
# Date :2016-08-30 | Unrealised Balance: 26617.29
# Date :2016-08-30 | Total Balance: 26367.39
# -------------------
# Bought 390 shares of NFLX at 103.33 per share worth 40298.70 $
# Date :2016-10-10 | Realised Balance: 28515.39
# Date :2016-10-10 | Unrealised Balance: 0.00
# Date :2016-10-10 | Total Balance: 28515.39
# Bought 275 shares of NFLX at 103.33 per share worth 28415.75 $
# Date :2016-10-10 | Realised Balance: -184.52
# Date :2016-10-10 | Unrealised Balance: 28415.75
# Date :2016-10-10 | Total Balance: 28231.23
# -------------------
# Sold 114 shares of GOOG at 53.24 per share worth 6068.85 $
# Date :2018-11-15 | Realised Balance: 5966.92
# Date :2018-11-15 | Unrealised Balance: 0.00
# Date :2018-11-15 | Total Balance: 5966.92
# Sold 112 shares of GOOG at 53.24 per share worth 5962.38 $
# Date :2018-11-15 | Realised Balance: 11869.67
# Date :2018-11-15 | Unrealised Balance: -5962.38
# Date :2018-11-15 | Total Balance: 5907.30
# ---------------------
# Sold 275 shares of NFLX at 270.60 per share worth 74415.00 $
# Date :2018-11-19 | Realised Balance: 73486.33
# Date :2018-11-19 | Unrealised Balance: 0.00
# Date :2018-11-19 | Total Balance: 73486.33
# Sold 271 shares of NFLX at 270.60 per share worth 73332.60 $
# Date :2018-11-19 | Realised Balance: 146085.61
# Date :2018-11-19 | Unrealised Balance: -73332.60
# Date :2018-11-19 | Total Balance: 72753.01
# ---------------------
# Sold 284 shares of AMZN at 83.18 per share worth 23622.27 $
# Date :2018-12-12 | Realised Balance: 23313.78
# Date :2018-12-12 | Unrealised Balance: 0.00
# Date :2018-12-12 | Total Balance: 23313.78
# Sold 280 shares of AMZN at 83.18 per share worth 23289.56 $
# Date :2018-12-12 | Realised Balance: 46370.45
# Date :2018-12-12 | Unrealised Balance: -23289.56
# Date :2018-12-12 | Total Balance: 23080.89
# ---------------------
# Sold 1077 shares of AAPL at 36.43 per share worth 39235.72 $
# Date :2018-12-21 | Realised Balance: 38593.46
# Date :2018-12-21 | Unrealised Balance: 0.00
# Date :2018-12-21 | Total Balance: 38593.46
# Sold 1059 shares of AAPL at 36.43 per share worth 38579.97 $
# Date :2018-12-21 | Realised Balance: 76787.63
# Date :2018-12-21 | Unrealised Balance: -38579.97
# Date :2018-12-21 | Total Balance: 38207.66
# ---------------------
# Bought 271 shares of NFLX at 361.21 per share worth 97887.91 $
# Date :2019-03-13 | Realised Balance: 47218.82
# Date :2019-03-13 | Unrealised Balance: 0.00
# Date :2019-03-13 | Total Balance: 47218.82
# Bought 130 shares of NFLX at 361.21 per share worth 46957.30 $
# Date :2019-03-13 | Realised Balance: -208.05
# Date :2019-03-13 | Unrealised Balance: 46957.30
# Date :2019-03-13 | Total Balance: 46749.25
# -------------------
# Bought 112 shares of GOOG at 58.65 per share worth 6568.91 $
# Date :2019-03-27 | Realised Balance: 5235.07
# Date :2019-03-27 | Unrealised Balance: 0.00
# Date :2019-03-27 | Total Balance: 5235.07
# Bought 89 shares of GOOG at 58.65 per share worth 5219.94 $
# Date :2019-03-27 | Realised Balance: -37.07
# Date :2019-03-27 | Unrealised Balance: 5219.94
# Date :2019-03-27 | Total Balance: 5182.87
# -------------------
# Bought 280 shares of AMZN at 95.11 per share worth 26631.50 $
# Date :2019-04-25 | Realised Balance: 19472.63
# Date :2019-04-25 | Unrealised Balance: 0.00
# Date :2019-04-25 | Total Balance: 19472.63
# Bought 204 shares of AMZN at 95.11 per share worth 19402.95 $
# Date :2019-04-25 | Realised Balance: -124.35
# Date :2019-04-25 | Unrealised Balance: 19402.95
# Date :2019-04-25 | Total Balance: 19278.60
# -------------------
# Bought 1059 shares of AAPL at 50.60 per share worth 53590.18 $
# Date :2019-05-06 | Realised Balance: 22661.55
# Date :2019-05-06 | Unrealised Balance: 0.00
# Date :2019-05-06 | Total Balance: 22661.55
# Bought 447 shares of AAPL at 50.60 per share worth 22620.22 $
# Date :2019-05-06 | Realised Balance: -184.87
# Date :2019-05-06 | Unrealised Balance: 22620.22
# Date :2019-05-06 | Total Balance: 22435.35
# -------------------
# Sold 89 shares of GOOG at 57.32 per share worth 5101.26 $
# Date :2019-07-17 | Realised Balance: 5013.18
# Date :2019-07-17 | Unrealised Balance: 0.00
# Date :2019-07-17 | Total Balance: 5013.18
# Sold 87 shares of GOOG at 57.32 per share worth 4986.62 $
# Date :2019-07-17 | Realised Balance: 9949.94
# Date :2019-07-17 | Unrealised Balance: -4986.62
# Date :2019-07-17 | Total Balance: 4963.31
# ---------------------
# Bought 87 shares of GOOG at 62.52 per share worth 5439.28 $
# Date :2019-07-26 | Realised Balance: 4456.26
# Date :2019-07-26 | Unrealised Balance: 0.00
# Date :2019-07-26 | Total Balance: 4456.26
# Bought 71 shares of GOOG at 62.52 per share worth 4438.96 $
# Date :2019-07-26 | Realised Balance: -27.09
# Date :2019-07-26 | Unrealised Balance: 4438.96
# Date :2019-07-26 | Total Balance: 4411.87
# -------------------
# Sold 130 shares of NFLX at 291.77 per share worth 37930.10 $
# Date :2019-08-28 | Realised Balance: 37342.75
# Date :2019-08-28 | Unrealised Balance: 0.00
# Date :2019-08-28 | Total Balance: 37342.75
# Sold 127 shares of NFLX at 291.77 per share worth 37054.79 $
# Date :2019-08-28 | Realised Balance: 74026.99
# Date :2019-08-28 | Unrealised Balance: -37054.79
# Date :2019-08-28 | Total Balance: 36972.20
# ---------------------
# Sold 204 shares of AMZN at 86.01 per share worth 17546.65 $
# Date :2019-10-10 | Realised Balance: 17246.84
# Date :2019-10-10 | Unrealised Balance: 0.00
# Date :2019-10-10 | Total Balance: 17246.84
# Sold 200 shares of AMZN at 86.01 per share worth 17202.60 $
# Date :2019-10-10 | Realised Balance: 34277.41
# Date :2019-10-10 | Unrealised Balance: -17202.60
# Date :2019-10-10 | Total Balance: 17074.81
# ---------------------
# Bought 127 shares of NFLX at 347.74 per share worth 44162.98 $
# Date :2020-01-30 | Realised Balance: 29422.38
# Date :2020-01-30 | Unrealised Balance: 0.00
# Date :2020-01-30 | Total Balance: 29422.38
# Bought 84 shares of NFLX at 347.74 per share worth 29210.16 $
# Date :2020-01-30 | Realised Balance: -79.88
# Date :2020-01-30 | Unrealised Balance: 29210.16
# Date :2020-01-30 | Total Balance: 29130.28
# -------------------
# Bought 200 shares of AMZN at 101.99 per share worth 20398.70 $
# Date :2020-02-05 | Realised Balance: 13674.73
# Date :2020-02-05 | Unrealised Balance: 0.00
# Date :2020-02-05 | Total Balance: 13674.73
# Bought 134 shares of AMZN at 101.99 per share worth 13667.13 $
# Date :2020-02-05 | Realised Balance: -129.07
# Date :2020-02-05 | Unrealised Balance: 13667.13
# Date :2020-02-05 | Total Balance: 13538.06
# -------------------
# Sold 71 shares of GOOG at 60.82 per share worth 4318.01 $
# Date :2020-04-21 | Realised Balance: 4247.74
# Date :2020-04-21 | Unrealised Balance: 0.00
# Date :2020-04-21 | Total Balance: 4247.74
# Sold 69 shares of GOOG at 60.82 per share worth 4196.37 $
# Date :2020-04-21 | Realised Balance: 8402.15
# Date :2020-04-21 | Unrealised Balance: -4196.37
# Date :2020-04-21 | Total Balance: 4205.78
# ---------------------
# Bought 69 shares of GOOG at 72.33 per share worth 4990.80 $
# Date :2020-06-08 | Realised Balance: 3361.44
# Date :2020-06-08 | Unrealised Balance: 0.00
# Date :2020-06-08 | Total Balance: 3361.44
# Bought 46 shares of GOOG at 72.33 per share worth 3327.20 $
# Date :2020-06-08 | Realised Balance: 0.96
# Date :2020-06-08 | Unrealised Balance: 3327.20
# Date :2020-06-08 | Total Balance: 3328.17
# -------------------
# Sold 134 shares of AMZN at 168.60 per share worth 22592.47 $
# Date :2021-04-19 | Realised Balance: 22237.47
# Date :2021-04-19 | Unrealised Balance: 0.00
# Date :2021-04-19 | Total Balance: 22237.47
# Sold 131 shares of AMZN at 168.60 per share worth 22086.66 $
# Date :2021-04-19 | Realised Balance: 44103.27
# Date :2021-04-19 | Unrealised Balance: -22086.66
# Date :2021-04-19 | Total Balance: 22016.60
# ---------------------
# Bought 131 shares of AMZN at 173.57 per share worth 22737.08 $
# Date :2021-04-29 | Realised Balance: 21138.81
# Date :2021-04-29 | Unrealised Balance: 0.00
# Date :2021-04-29 | Total Balance: 21138.81
# Bought 121 shares of AMZN at 173.57 per share worth 21001.43 $
# Date :2021-04-29 | Realised Balance: -72.63
# Date :2021-04-29 | Unrealised Balance: 21001.43
# Date :2021-04-29 | Total Balance: 20928.80
# -------------------
# Sold 84 shares of NFLX at 489.43 per share worth 41112.12 $
# Date :2021-06-03 | Realised Balance: 40621.12
# Date :2021-06-03 | Unrealised Balance: 0.00
# Date :2021-06-03 | Total Balance: 40621.12
# Sold 82 shares of NFLX at 489.43 per share worth 40133.26 $
# Date :2021-06-03 | Realised Balance: 80353.04
# Date :2021-06-03 | Unrealised Balance: -40133.26
# Date :2021-06-03 | Total Balance: 40219.78
# ---------------------
# Bought 82 shares of NFLX at 517.92 per share worth 42469.44 $
# Date :2021-08-16 | Realised Balance: 37458.91
# Date :2021-08-16 | Unrealised Balance: 0.00
# Date :2021-08-16 | Total Balance: 37458.91
# Bought 72 shares of NFLX at 517.92 per share worth 37290.24 $
# Date :2021-08-16 | Realised Balance: -204.23
# Date :2021-08-16 | Unrealised Balance: 37290.24
# Date :2021-08-16 | Total Balance: 37086.01
# -------------------
# Sold 121 shares of AMZN at 139.99 per share worth 16938.31 $
# Date :2022-01-25 | Realised Balance: 16696.30
# Date :2022-01-25 | Unrealised Balance: 0.00
# Date :2022-01-25 | Total Balance: 16696.30
# Sold 119 shares of AMZN at 139.99 per share worth 16658.33 $
# Date :2022-01-25 | Realised Balance: 33188.05
# Date :2022-01-25 | Unrealised Balance: -16658.33
# Date :2022-01-25 | Total Balance: 16529.71
# ---------------------
# Sold 72 shares of NFLX at 405.60 per share worth 29203.20 $
# Date :2022-02-03 | Realised Balance: 28706.94
# Date :2022-02-03 | Unrealised Balance: 0.00
# Date :2022-02-03 | Total Balance: 28706.94
# Sold 70 shares of NFLX at 405.60 per share worth 28392.00 $
# Date :2022-02-03 | Realised Balance: 56815.02
# Date :2022-02-03 | Unrealised Balance: -28392.00
# Date :2022-02-03 | Total Balance: 28423.02
# ---------------------
# Sold 46 shares of GOOG at 132.12 per share worth 6077.61 $
# Date :2022-03-04 | Realised Balance: 6017.80
# Date :2022-03-04 | Unrealised Balance: 0.00
# Date :2022-03-04 | Total Balance: 6017.80
# Sold 45 shares of GOOG at 132.12 per share worth 5945.49 $
# Date :2022-03-04 | Realised Balance: 11903.83
# Date :2022-03-04 | Unrealised Balance: -5945.49
# Date :2022-03-04 | Total Balance: 5958.34
# ---------------------
# Sold 447 shares of AAPL at 145.18 per share worth 64894.72 $
# Date :2022-06-03 | Realised Balance: 64060.90
# Date :2022-06-03 | Unrealised Balance: 0.00
# Date :2022-06-03 | Total Balance: 64060.90
# Sold 441 shares of AAPL at 145.18 per share worth 64023.65 $
# Date :2022-06-03 | Realised Balance: 127444.32
# Date :2022-06-03 | Unrealised Balance: -64023.65
# Date :2022-06-03 | Total Balance: 63420.67
# ---------------------
# -----------------------------------
# Closed open trades for -441 shares of AAPL at 136.53 per share worth -60209.88 $
# Date :2022-06-30 | Total Balance: 67234.43
# The total capital at end of strategy for AAPL: 67234.43
# The strategy returns on investment are 572.34 %
# Total trades by strategy for AAPL: 16.00
# -----------------------------------
# Closed open trades for -45 shares of GOOG at 109.37 per share worth -4921.76 $
# Date :2022-06-30 | Total Balance: 6982.07
# The total capital at end of strategy for GOOG: 6982.07
# The strategy returns on investment are -30.18 %
# Total trades by strategy for GOOG: 36.00
# -----------------------------------
# Closed open trades for -70 shares of NFLX at 174.87 per share worth -12240.90 $
# Date :2022-06-30 | Total Balance: 44574.12
# The total capital at end of strategy for NFLX: 44574.12
# The strategy returns on investment are 345.74 %
# Total trades by strategy for NFLX: 28.00
# -----------------------------------
# Closed open trades for -119 shares of AMZN at 106.21 per share worth -12638.99 $
# Date :2022-06-30 | Total Balance: 20549.06
# The total capital at end of strategy for AMZN: 20549.06
# The strategy returns on investment are 105.49 %
# Total trades by strategy for AMZN: 28.00
# -----------------------------------
# ---------- Portfolio statistics ----------
# Total trade count 108
# Total transaction cost: 20542.71 $
# Starting capital: 40000
# Final capital: 139339.68
# Log Portfolio returns: 124.80 %
# Normal Portfolio returns: 248.35 %
# Portfolio Annual Mean returns: 0.12
# Portfolio Annual Regular std: 0.26
# Portfolio Annual Sharpe Ratio: 0.45
# ^GSPC Benchmark Annual Mean returns: 0.10
# Annual Information Ratio: 0.06
# Portfolio Treynor Ratio: 0.18
# Portfolio Calmar Ratio: 0.03
# Portfolio Sortino Ratio: 0.62
#             portfolio_tb  portfolio_ub  portfolio_rb  portfolio_daily_returns  \
# 2011-01-25  39600.465369  39953.463086   -352.997717                -0.010039
# 2011-01-26  39344.935515  39697.933232   -352.997717                -0.006474
# 2011-01-27  41330.669468  41683.667185   -352.997717                 0.049238
# 2011-01-28  40495.113651  40848.111368   -352.997717                -0.020424
# 2011-01-31  40286.031155  40639.028872   -352.997717                -0.005177
# 2011-02-01  40701.919900  41054.917617   -352.997717                 0.010270
# 2011-02-02  40689.284394  41042.282111   -352.997717                -0.000310
# 2011-02-03  40656.174891  41009.172608   -352.997717                -0.000814
# 2011-02-04  41343.086234  41696.083951   -352.997717                 0.016754
# 2011-02-07  41472.672320  41825.670037   -352.997717                 0.003130
# 2011-02-08  41989.856335  42342.854052   -352.997717                 0.012393
# 2011-02-09  42421.867684  42774.865401   -352.997717                 0.010236
# 2011-02-10  42415.005111  42768.002828   -352.997717                -0.000162
# 2011-02-11  43204.906849  43557.904566   -352.997717                 0.018452
# 2011-02-14  44278.599542  44631.597259   -352.997717                 0.024547
# 2011-02-15  43795.437125  44148.434842   -352.997717                -0.010972
# 2011-02-16  43590.811584  43943.809301   -352.997717                -0.004683
# 2011-02-17  43418.976188  43771.973905   -352.997717                -0.003950
# 2011-02-18  43192.404351  43545.402068   -352.997717                -0.005232
# 2011-02-22  41435.361972  41788.359689   -352.997717                -0.041530
#
#             Benchmark Returns  portfolio-benchmark  \
# 2011-01-25           0.000263            -0.010302
# 2011-01-26           0.004212            -0.010686
# 2011-01-27           0.002242             0.046996
# 2011-01-28          -0.018014            -0.002410
# 2011-01-31           0.007633            -0.012810
# 2011-02-01           0.016556            -0.006285
# 2011-02-02          -0.002726             0.002416
# 2011-02-03           0.002351            -0.003165
# 2011-02-04           0.002880             0.013874
# 2011-02-07           0.006221            -0.003091
# 2011-02-08           0.004176             0.008217
# 2011-02-09          -0.002790             0.013026
# 2011-02-10           0.000749            -0.000911
# 2011-02-11           0.005492             0.012960
# 2011-02-14           0.002382             0.022165
# 2011-02-15          -0.003240            -0.007732
# 2011-02-16           0.006238            -0.010921
# 2011-02-17           0.003071            -0.007021
# 2011-02-18           0.001923            -0.007155
# 2011-02-22          -0.020742            -0.020788
#
#             portfolio_gross_cum_returns  portfolio_gross_cum_max_returns
# 2011-01-25                     0.990012                         0.990012
# 2011-01-26                     0.983623                         0.990012
# 2011-01-27                     1.033267                         1.033267
# 2011-01-28                     1.012378                         1.033267
# 2011-01-31                     1.007151                         1.033267
# 2011-02-01                     1.017548                         1.033267
# 2011-02-02                     1.017232                         1.033267
# 2011-02-03                     1.016404                         1.033267
# 2011-02-04                     1.033577                         1.033577
# 2011-02-07                     1.036817                         1.036817
# 2011-02-08                     1.049746                         1.049746
# 2011-02-09                     1.060547                         1.060547
# 2011-02-10                     1.060375                         1.060547
# 2011-02-11                     1.080123                         1.080123
# 2011-02-14                     1.106965                         1.106965
# 2011-02-15                     1.094886                         1.106965
# 2011-02-16                     1.089770                         1.106965
# 2011-02-17                     1.085474                         1.106965
# 2011-02-18                     1.079810                         1.106965
# 2011-02-22                     1.035884                         1.106965
